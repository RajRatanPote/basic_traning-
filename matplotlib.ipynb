# %%
# %matplotlib inline 
from matplotlib import pyplot as plt

# %%
plt.plot([1,2,3],[9,8,10])
plt.show()

# %%
plt.plot([1,2,3],[9,8,10])
plt.title("Title")
plt.xlabel("this is x")
plt.ylabel("this is y")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
from matplotlib import style
style.use("ggplot")
x=[1,4,7]
y=[2,2,8]
x1=[3,6,9]
y1=[1,5,9]
plt.hist(x,y,label="first", linewidth=2)
plt.plot(x1,y1 ,label="2nd", linewidth=3)
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [raw]
# from pandas import read_csv
# from matplotlib import pyplot
# series = read_csv('daily-minimum-temperatures.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
# print(series.head())

# %%
from pandas import read_csv
from matplotlib import pyplot
series = read_csv('one.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
print(series.head())
# Out:
# Date
# 1981-01-01    20.7
# 1981-01-02    17.9
# 1981-01-03    18.8
# 1981-01-04    14.6
# 1981-01-05    15.8
# Name: Temp, dtype: float64

# %%
from pandas import read_csv
from matplotlib import pyplot
series = read_csv('one.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
series.plot()
pyplot.show()

# %%
from pandas import read_csv
from matplotlib import pyplot
s = read_csv('one.csv', header=0,index_col=0, parse_dates=True, squeeze=True)
s.plot(style='k.')
pyplot.show()

# %%
from pandas import read_csv
from pandas import DataFrame
from pandas import Grouper 
from matplotlib import pyplot 
s= read_csv('one.csv', header= 0,index_col=0,parse_dates=True,squeeze =True)
groups= s.groupby(Grouper(freq='A'))
year = DataFrame()
for name, group in groups:
    year[name.year] = group.values
year.plot(subplots = True, legend=False)
pyplot.show()

# %%
from pandas import read_csv
from matplotlib import pyplot
s=read_csv('one.csv',header=0,index_col=0,parse_dates = True, squeeze=True)
s.hist()
pyplot.show()

# %%
from pandas import read_csv
from matplotlib import pyplot
s=read_csv('one.csv',header=0, index_col=0, parse_dates=True,squeeze = True)
s.plot(kind='kde')
pyplot.show()

# %%
from pandas import read_csv
from pandas import DataFrame
from pandas import Grouper
from matplotlib import pyplot
s= read_csv('one.csv',header=0,index_col=0,parse_dates=True, squeeze= True)
groups=s.groupby(Grouper(freq='A'))
year= DataFrame()
for name,group in groups:
    year[name.year]=group.values
year.boxplot()
pyplot.show()

# %%
from pandas import read_csv
from pandas import DataFrame
from pandas import Grouper
from matplotlib import pyplot
from pandas import concat
s=read_csv('one.csv',header=0,index_col=0, parse_dates=True,squeeze=True)
oy= s['1990']
groups=oy.groupby(Grouper(freq='M'))
m= concat([DataFrame(x[1].values) for x in groups], axis=1)
m=DataFrame(m)
m.columns=range(1,13)
m.boxplot()
pyplot.show()

# %%
from pandas import read_csv
from pandas import DataFrame
from pandas import Grouper
from matplotlib import pyplot
series=read_csv('one.csv',header=0,index_col=0,parse_dates=True, squeeze=True)
groups= series.groupby(Grouper(freq='A'))
year=DataFrame()
for name,group in groups:
    year[name.year]=group.values
year=year.T
pyplot.matshow(year,interpolation=None,aspect='auto')
pyplot.show()

# %%
from pandas import read_csv
from pandas import DataFrame
from pandas import Grouper
from matplotlib import pyplot
from pandas import concat
s = read_csv('one.csv', header=0,index_col=0, parse_dates=True,squeeze=True)
o_y= s['1990']
g = o_y.groupby(Grouper(freq='M'))
m = concat([DataFrame(x[1].values)for x in groups], axis=1)
m = DataFrame(m)
m.columns = range(1,11)
pyplot.matshow(m, interpolation=None, aspect='auto')
pyplot.show()

# %%
# Scatter plot

# %%
from pandas import read_csv
from matplotlib import pyplot
from pandas.plotting import lag_plot
s=read_csv('one.csv',header=0, index_col=0,parse_dates=True, squeeze=True)
lag_plot(s)
pyplot.show()

# %%
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from matplotlib import pyplot 
from pandas.plotting import scatter_matrix
s=read_csv('one.csv',header=0,index_col=0,parse_dates=True,squeeze=True)
v=DataFrame(s.values)
lags=7
columns =[v]
for i in range(1,(lags+1)):
    columns.append(v.shift(i))
df = concat(columns,axis=1)
columns =['t+1']
for i in range(1,(lags +1 )):
    columns.append('t-' + str(i))
df.columns = columns
pyplot.figure(1)
for i in range(1,(lags +1)):
    ax= pyplot.subplot(240 +i)
    ax.set_title('t+1 vs t-' + str(i))
    pyplot.scatter(x=df['t+1'].values, y=df['t-'+str(i)].values)
pyplot.show()

# %%
from pandas import read_csv
from matplotlib import pyplot
from pandas.plotting import autocorrelation_plot
s=read_csv('one.csv',header=0,index_col=0,parse_dates=True,squeeze=True)
autocorrelation_plot(s)
pyplot.show()
